# %%
it is also called HCA (Hierarchical Clustering Analysis)
The clusters are represented like tree like structure called DENDOGRAM
---> ther are 2 techniques here:
        - AGLOMERATIVE technique
        - Divisive technique

# %% [markdown]
# # AGLOMERATIVE technique

# %%
                    "Aglomerative is a bottom up approach where algorithm 
                    starts by taking all data points as a single cluster
                    and merging them until one cluster is left"

this is bottom up approach h, yani agr hmary pas A,B,C,D,E y data points hn to clusters esy
bny gy k phly hm A B C D E ka it self cluster bnay gy yani ek ek element in one cluster then hm 
AB ka ek cluster bna den gy because they have small Euclidean distance and then C nad D ka euclidean distance
kam h ti CD ka ek cluster bna den gy then E ka distance bhi in k saath kam h to E ko bhi isi cluster m daal den gy , then hm 
in sab choty clusters ko mila kr ek bra cluister bnay gy jis m ABCDE sab hin gy, this is bottom up approach
----> and dendogram here is made like this:

# %%
from IPython.display import Image
Image(filename='Aglomerative.png', width=300, height=300)

# %% [markdown]
# # Devisive technique

# %%
y aglomerative k opposite h, yani is m ABCDE s start kry gy and break krty krty A,B,C,D,E alg alg tak
phunchyn gy

# %%
from IPython.display import Image
Image(filename='divisive.png', width=300, height=300)

# %%
THESE ARE TECHNIQUES TO CALCULATE BEST NUMBER OF CLUSTERS

# %%
from IPython.display import Image
Image(filename='1.jpeg', width=300, height=300)

# %%
from IPython.display import Image
Image(filename='2.jpeg', width=300, height=300)

# %%
from IPython.display import Image
Image(filename='3.jpeg', width=300, height=300)

# %%
from IPython.display import Image
Image(filename='4.jpeg', width=300, height=300)

# %%
from IPython.display import Image
Image(filename='5.jpeg', width=300, height=300)

# %% [markdown]
# # now, how to calculate best number of clusters?

# %%
1- dendogram m vo sab s bri line pick kro jis ko koi cut nhi kr rha,
2- phir us k mid s ek horizontal line cut kro
3- or us ky neechy ki left size vala ek cluster ho ga and right vaa ek cluster ho ga

----> yani in this case, ABC and D are 2 clusters, 
step are represented by black pen in picture

# %%
from IPython.display import Image
Image(filename='best_clusters.png', width=300, height=300)
