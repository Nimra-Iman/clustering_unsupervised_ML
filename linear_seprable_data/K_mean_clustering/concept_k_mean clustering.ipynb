# %%
the best real life example of clustering is google photos m explore m ja kr dekho, starting m hi similar 
faces vali saari pictures us n ek folder m daal di, folder mean to say jha faces k choty choty icons show ho rhy

# %%
step 1- K mean clustering esy work krti h k sab s phly data m randomly 2 centroids yani 2 center points liye jaty hn
and then un ko join kr dety hn
    y jo red s picture m show ho rhy y 2 centroids hn jin ko hm n apas m mila dia

# %%
from IPython.display import Image
Image(filename='step1.png', width=300, height=300)

# %%
step 2- phir jab hm n y line bna li shown in blue color to is k mid s hm straight line bnaty, and then
strainght line k ek side vala ek cluster and other vala ek cluster

# ab y jis ko black s highlight kia y ek strainght line ho gi and then jis ko yellow highlighter s highlight kiye huye
# y 2 clusters ho gay

# %%
from IPython.display import Image
Image(filename='step2.png', width=300, height=300)

# %%
step 3: ab problem y h k y clusters perfect nhi bny, ab y jo 2 clusters bny in k saary elemenst ka mean lia jay ga
, let jo uper vala h us ka mean 2 aya or jo red point yani centroid select hua agr mean k equal nhi h to yani k y acha centroid 
nhi h and is ki vja s achy clusters nhi bny, yani hm centroid ko shift kr k again un ko mila kr straight line bna kr clusters
bnay gy jo k perfect clusters hon gy

# ab y jo black points show kiye huy hn y mean valy points h yani hm n old centroids(red points) ko new centroids (black points)
# m transfer kia, again line bnai and then clusters bny jo k perfect th

# %%
from IPython.display import Image
Image(filename='step3.png', width=300, height=300)

# %%
---> ab baat ati h k hmy y kesy pta lgy ga k kitny clusters aty hn, q k hmy hr cluster m s to ek
randomly centroid ya center point uthana hota to y kesy pta lgy ga k kitny clusters bny gy to 
is k liye we use ELBOW METHOD

# %% [markdown]
# # elbow method

# %%
hm starting m 2 clusters choose kr lety hn and WCSS approach ko use krty hn WCSS stands for EITHIN CLUSTER SUM OF SQUARE
yani un clusters k centroids ki value s saary data points
jo us cluster m h us ka distance calculate kryn gy, then un sab distances ka square kr len gy, or un values ko add kr
den gy 

then 2nd cluster k saath bhi esa hi kryn gy then us ki bhi value len len gy

then hm 3rd cluster bnay gy or us ki bhi value len len gy

---> phir jab hm graph bnay gy number of clusters and their respective values ka to hmy graph m jha elbow vala
point mila to vo hmary total number of clusters hon gy

# %%
from IPython.display import Image
Image(filename='elbow.png', width=300, height=300)

# %%
ab baaz oqat hm jo clusters bnaty hn or jo hm n best centroids ki value bhi nikal li jo k clusters ka
asal m mean tha or vo mean yani centroids itny qareeb qareeb thy k jab hm n staringht lines bnai to clusters achy nhi
bny to K-MEAN++ ko use krty hn jo k center point ko door door kr deta h

# %%
from IPython.display import Image
Image(filename='1.jpeg', width=300, height=300)

# %%
from IPython.display import Image
Image(filename='2.jpeg', width=300, height=300)

# %%
from IPython.display import Image
Image(filename='3.jpeg', width=300, height=300)

# %%
from IPython.display import Image
Image(filename='4.jpeg', width=300, height=300)

# %% [markdown]
# ## K-MEAN CLUSTERING IS BEST ONLY FOR LINEARLY SEPARABLE DATA
