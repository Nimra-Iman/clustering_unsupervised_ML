# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.datasets import make_moons
x,y=make_moons(n_samples=250, noise=0.05)
data={"A":x[:,0], 'B':x[:,1], 'output':y}
dataset=pd.DataFrame(data)
dataset.head()
# Out:
#           A         B  output
# 0  0.671089  0.626671       0
# 1  0.379804 -0.361227       1
# 2  1.955817  0.349632       1
# 3  0.212912 -0.194480       1
# 4  0.517443 -0.400642       1

# %%
plt.figure(figsize=(5,3))
sns.scatterplot(x='A',y='B', data=dataset, hue='output')
plt.show()

# %%
from sklearn.cluster import DBSCAN
clust=DBSCAN(eps=0.2,min_samples=5)
# min_samples=5 s murad y h k jo circle ap n bnana h us m minimum kitny data points ho skty hn

# eps=0.5 rkha yani ziada radius rkha to us n ek hi cluster bna dia sara

# %%
d['target']=pd.DataFrame(clust.fit_predict(d))

# %%
plt.figure(figsize=(5,3))
sns.scatterplot(x='A',y='B', data=d, hue='target')
plt.show()

# %%
# original m bhi esy hi clusters bny jesy predicted m bny :D
