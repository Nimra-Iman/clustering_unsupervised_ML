# %%
it is used to check whether the clusters determined by k-means clusetring and hierarchy clustering methods are 
true or not, Its value ranges from -1 to +1 , if the Silhouette score valus is close to +1 it means that total 
nuber of clusters calculated are true and if it is close to -1 , it means that these are not total number of
clusters that you calculated.

# %%
from IPython.display import Image
Image(filename='Silhouette score formula.png', width=400, height=400)

# %%
ab Silhouette score vala formuala m yani s(i) valy formula m b(i) and a(i) smjhty hn

# %% [markdown]
# # a(i) in formula?

# %%
a(i) is intra_cluster distance, yani ek cluster m e.g: A,B,C,D y 4 data points hn to A ka B and C and D k saath
distance nikaly gy , and similarly B ka bhi sab k saath distance nikaly gy and then C and D ka bhi sab sab k saath distance
nikaly gy, then un sab distances ka mean claculate kryn gy but mean esy calculate krna h k sum/(total_elements-1) krna h
ab -1 is liye kia q k Since we don't include the distance from point i to itself (which is 0), the number of distances
we're averaging is ∣C∣−1.

# %%
from IPython.display import Image
Image(filename='a(I) and b(i) formula.png', width=300, height=300)

# %% [markdown]
# # b(i) in formula?

# %%
ab e.g: hmary pas 2 clusters bny hn, cluster A and Cluster B, ab cluster B ka ek esa point jo k Cluster
A k saath milta tha to us point ka hm Cluster A k hr ek ek point k saath distance calculate kryn gy and un saary
distances ka mean calculate kr len gy,,,,,, ab b(i) valy formula m "min" is liye h q k hmy doosry cluster ka vo point
uthana h jo k is cluster s minimum distance pr ho, as shown in figure

# %%
from IPython.display import Image
Image(filename='example.png', width=300, height=300)

# %%
------------>> to make value of Silhouette score close to +1, we need to lesser the value of 
a(i) than b(i) because a(i) is intra_cluster distance and b(i) is inter_cluster distance, if the distance of an 
element with its own cluster is less( a(i) ) and distance between 2 clusters are large( b(i) ), then they are
goor clusters and Silhouette score value will be close to 1
